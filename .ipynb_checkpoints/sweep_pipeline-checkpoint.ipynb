# %%
import sweep_download
from sweep_main import run_sweep_viz,make_sweep_data,get_visualization
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[52], line 2
#       1 import sweep_download
# ----> 2 from sweep_main import run_sweep_viz,make_sweep_data,get_visualization
#
# ImportError: cannot import name 'get_visualization' from 'sweep_main' (C:\Users\adsir\OneDrive\Desktop\Content\New Research\SWEEP\sweep_main.py)

# %%
SELECT_YEAR = 2025 #Enter value between 2001 and 2025 corresponding to the main year of the season (ex: playoff games in January 2026 will require 2025)
SELECT_WEEK = 19     #Enter value from 1 to 22 (Superbowl). Note that before extra game introduced values range from 0 to 21
SELECT_TEAM = 'BUF'

# %%
NFL_DATA = download_nfl_data_season(2025)
# Out:
# ...
# C:\Users\adsir\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\adsir\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'release-assets.githubusercontent.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ✓ Download complete
# ✓ Loaded 48,771 plays

# %%
GAME_IDS = sweep_download.view_games(NFL_DATA,week=SELECT_WEEK,team=SELECT_TEAM)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 GAME_IDS = sweep_download.view_games(NFL_DATA,week=SELECT_WEEK,team=SELECT_TEAM)
#
# AttributeError: module 'sweep_download' has no attribute 'view_games'

# %%
def get_visualization(season_data,year,team):
    if week == None:
        pass
    else:
        season_data_ = season_data_[season_data_['week']==week]
    if team == None:
            pass
    else:
        season_data_ = season_data_[(season_data_['home_team']==team)|(season_data_['away_team']==team)]
    if len(season_data_[['game_id','week','home_team','away_team','week']].drop_duplicates()['game_id'])==0:
        print("This game does not exist!")
        return None
    elif len(season_data_[['game_id','week','home_team','away_team','week']].drop_duplicates()['game_id'])>1:
        print("This returns too many games, specify a team AND a week!") 
        return None
    else:
        game_data = season_data_
        print("preparing_sweep_data")
        sweep_data = make_sweep_data(game_data)
        sweep_viz = run_sweep_viz(sweep_data)
        sweep_viz.show()
    return sweep_viz

# %%
GAME_IDS[0]
# Out:
# ['2025_19_BUF_JAX']

# %%
DATA =
